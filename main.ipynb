# %% [markdown]
# # Training Auto Encoder

# %%
from Autoencoder import layers, autoencoder, callbacks, dataset, trainloop

import matplotlib.pyplot as plt 
import tensorflow as tf

# %%
def main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log):
    train = trainloop.Train(model, loss, optimizer, model_ckpt, history_log)
    trained_model, history = train.trainLoop(train_ds, validation_ds, debug = True)
    
    return trained_model, history

# %%
import tensorflow as tf

if __name__ == "__main__":
    
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
    
        
    ds = dataset.Dataset(X_train, y_train)
    train_ds, validation_ds = ds.dataset(True)
    plt.show() 
    
    model = autoencoder.AutoEncoder()
    loss = layers.Losses()
    optimizer = tf.keras.optimizers.Adam(5)
    model_ckpt = "ckpt"
    history_log = "history"
    
    trained_model, history = main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log)
# Out:
# E:\fashionmnist\Autoencoder\dataset.py:74: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = plt.subplot(len(augmented_image) / columns + 1, columns, i + 1)
# Tensorflow version: 2.4.0
# Eager execution: True
# No checkpoint provided, begin training
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=int32, numpy=5>
# 1718/1718 [==============================] - 284s 165ms/step - train_mse: nan - train_entropy: nan 1:47 - train_mse:  - - ETA: 4:00 - train_mse: nan - train_entropy: n - ETA: 4:02 - train_mse: nan - train_entropy: - ETA: 4:05 - train_m - ETA: 4:15 - train_mse: nan  - ETA: 4:16 - train_mse: nan - train_en - ETA: 4:15 - tra - ETA: 4:21 - train_mse: nan - train_entropy: n - ETA:  - ETA: 4:19 - ETA: 4:11 - train_mse: nan - train_entr - ETA: 4: - ETA: 3:56 - t - ETA: 3:55 - ETA: 3:54 - train_mse: nan - train_entropy: n - ETA: 3:54 - train_mse: nan - train_entrop - ETA: 3:53 - ETA: 3:52 - train_mse: nan -  - ETA: 3:52 - train_mse: nan - trai - ETA: 3:52 - train_mse: nan - train_entropy: - ETA:  - ETA: 3:18 - train_mse:  - ETA: 3: - ETA: 3:15 - train_mse: nan - train_entropy: - ETA: 3:15 - train_mse: nan -  - ETA: 3:14 - train_mse: nan - train_en - ETA: 3:14 - t - ETA: 3:09 - train_mse: nan - tr - ETA: 3:07 - train - ETA: 3:05 - train_mse: nan - trai - ETA: 3:04 - train_mse: nan - train_entropy: n - ETA: 3:04 - train_mse: nan - tr - ETA: 3:00 - train_mse: nan -  - ETA: 2:57 - ETA: 2: - ETA: 2:51 - train_mse: nan - train_entrop - ETA: 2:51 - train_mse: nan - train_entrop - ETA: 2:50 - train_mse - ETA: 2:49 - train_mse: nan - train_entr - ETA: 2:48 - train_mse: nan - tr - ETA - ETA: 2:44 - train_mse: nan - train_entropy: n - ETA: 2:44 - train - ETA: 2:42 - train_mse: nan - tr - ETA: 2:40 - train_mse - ETA: 1:45 - train_mse: nan - train_entr - ETA: 1:45 - train_mse: nan -  - ETA: 1:44 - train_mse: nan - train_entrop - ETA: 1: - ETA: 1:40 - train_mse: nan - train_entrop - ETA: 1:40 - train_mse: nan - train_entrop - - ETA: 1:36 - train_mse: nan - tr - ETA: 1:35 - train_mse: nan  - ETA: 1:34 - train_mse: nan - train_entropy: - ETA: 1:33 - train_mse: nan - tr - ETA: 1:32 - train_mse: na - ETA: 1:27 - train_mse: nan - train_entropy: - ETA: 1:27 - train_mse: nan - train_entr - ETA: 1:26 - train - ETA: 1:24 - train_mse: nan - train_entrop - ETA: 1:24 - train_mse: nan - train_en - ETA: 1:19 - train_mse: nan - train_entropy: n - ETA: 1:19 - train_mse: nan - train_entrop - E - ETA: 1:00 - train_mse: - ETA: 57s - train_mse: nan - train_entropy:  - ETA: 56s - train_mse: nan - train_entropy: - ETA: 55s - train_mse: nan - train_entro - ETA: 54s - train_mse: nan - train_ - ETA: 52s - train_mse: nan - train_entrop - ETA: 51s - train_mse: nan - train_entr - ETA: 50s - train_mse: nan - - ETA: 47s - train_mse: nan - train_entropy - ETA: 46s - tra - ETA: 41s - train_mse: nan - train_ent - ETA: 40s - train_mse: nan - t - ETA: 37s - train_mse: nan - train_entropy: n - ETA: 37s - train_mse: nan - train_entropy - ETA: 36s - train_mse: nan - train_entrop - ETA: 35s - train_mse: nan - trai - ETA: 33s - train_mse: nan - train_entropy:  - ETA: 32s - train_mse: nan - train_entropy:  - ETA: 32s - train_mse: nan - t - ETA: 29s - train_mse: nan - train_ - ETA: 19s - train_mse: nan  - ETA: 16s - train_mse: nan - train_entro - ETA: 15s - train_mse: nan -  - ETA: 3s - train_mse:  - ETA: 1s - train_mse: nan - trai
# 156/156 [==============================] - ETA: 0s - valid_mse: nan - valid_entropy: nan - ETA: 6s - valid_mse: nan - va - ETA: 7s - valid_mse: nan - valid_ - ETA: 1s - valid_mse: nan - valid_entrop - ETA: 1s - v - ETA: 1s - valid_mse: nan - valid_entropy: n - ETA: 0s - valid_mse: nan - valid_en - 290s 41ms/step - valid_mse: nan - valid_entropy: nan
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ce697959c6a5> in <module>
#      16     history_log = "history"
#      17
# ---> 18     trained_model, history = main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log)
#
# <ipython-input-2-dfbff3a9baac> in main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log)
#       1 def main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log):
#       2     train = trainloop.Train(model, loss, optimizer, model_ckpt, history_log)
# ----> 3     trained_model, history = train.trainLoop(train_ds, validation_ds, debug = True)
#       4
#       5     return trained_model, history
#
# E:\fashionmnist\Autoencoder\trainloop.py in trainLoop(self, train, validation, epochs, debug)
#      39
#      40             train_log = self.train_step()
# ---> 41             valid_log = self.valid_step(epoch)
#      42             history = self.callback.on_epoch_end(epoch, train_log, valid_log, self.model)
#      43
#
# ~\miniconda3\envs\cs_ftmle\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     822     if RUN_FUNCTIONS_EAGERLY:
#     823       with trace.Trace(self._name, tf_function_call="eager"):
# --> 824         return self._python_function(*args, **kwds)
#     825
#     826     tracing_count = self.experimental_get_tracing_count()
#
# ~\miniconda3\envs\cs_ftmle\lib\site-packages\tensorflow\python\eager\function.py in bound_method_wrapper(*args, **kwargs)
#    3880       if tf_inspect.ismethod(wrapped_fn):
#    3881         wrapped_fn = six.get_unbound_function(wrapped_fn)
# -> 3882       return wrapped_fn(weak_instance(), *args, **kwargs)
#    3883
#    3884     # If __wrapped__ was replaced, then it is always an unbound function.
#
# E:\fashionmnist\Autoencoder\trainloop.py in valid_step(self, epoch)
#      93
#      94         # if epoch % 10 == 0:
# ---> 95         self.callback._plot_image(x_train, predicted_image, x_label, predicted_label)
#      96
#      97         return [tf.reduce_mean(loss).numpy() for loss in avg_loss]
#
# E:\fashionmnist\Autoencoder\callbacks.py in _plot_image(x_train, predicted_image, x_label, predicted_label)
#     138         fig, ax = plt.subplots(1, 2, figsize = (10, 10))
#     139         ax[0].imshow(predicted_image[sample].reshape(28, 28), cmap = "gray")
# --> 140         ax[0].set_title(f"Created image predicted {label[np.argmax(predicted_label[sample])]} for {label[x_label]}")
#     141
#     142         ax[1].imshow(ground_truth[sample].reshape(28, 28), cmap = "gray")
#
# TypeError: unhashable type: 'numpy.ndarray'
# C:\Users\PC\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\image.py:447: UserWarning: Warning: converting a masked element to nan.
#   dv = np.float64(self.norm.vmax) - np.float64(self.norm.vmin)
# C:\Users\PC\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\image.py:454: UserWarning: Warning: converting a masked element to nan.
#   a_min = np.float64(newmin)
# C:\Users\PC\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\image.py:459: UserWarning: Warning: converting a masked element to nan.
#   a_max = np.float64(newmax)
# C:\Users\PC\miniconda3\envs\cs_ftmle\lib\site-packages\matplotlib\image.py:479: UserWarning: Warning: converting a masked element to nan.
#   dtype=scaled_dtype)

# %% [markdown]
# # Training Classifcation Model
