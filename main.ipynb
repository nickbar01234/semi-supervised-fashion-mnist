# %% [markdown]
# # Training Auto Encoder

# %%
from Autoencoder import layers, autoencoder, callbacks, dataset, trainloop

import matplotlib.pyplot as plt

# %%
def main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log):
    train = trainloop.Train(model, loss, optimizer, model_ckpt, history_log)
    trained_model, history = train.trainLoop(train_ds, validation_ds, debug = True)
    
    return trained_model, history

# %%
import tensorflow as tf

if __name__ == "__main__":
    
    (X_train, y_train), (X_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()
    X_train = X_train.reshape(-1, 28, 28, 1)
    
        
    ds = dataset.Dataset(X_train)
    train_ds, validation_ds = ds.dataset(True)
    plt.show() 
    
    model = autoencoder.AutoEncoder()
    loss = layers.Losses()
    optimizer = tf.keras.optimizers.Adam()
    model_ckpt = "ckpt"
    history_log = "history"
    
    trained_model, history = main(model, train_ds, validation_ds, loss, optimizer, model_ckpt, history_log)
# Out:
# E:\fashionmnist\Autoencoder\dataset.py:65: MatplotlibDeprecationWarning: Passing non-integers as three-element position specification is deprecated since 3.3 and will be removed two minor releases later.
#   ax = plt.subplot(len(augmented_image) / columns + 1, columns, i + 1)
# Tensorflow version: 2.4.0
# Eager execution: True
# No checkpoint provided, begin training
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# 1718/1718 [==============================] - 248s 144ms/step - Train: 0.0990
# 156/156 [==============================] - 257s 54ms/step - Valid: 0.0947
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009970046>
# 1718/1718 [==============================] - 519s 152ms/step - Train: 0.0960
# 156/156 [==============================] - 529s 63ms/step - Valid: 0.0934
# For epoch 2, loss 0.092153564 improved from 0.09467853
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009910405>
# 1718/1718 [==============================] - 829s 174ms/step - Train: 0.0944
# 156/156 [==============================] - 837s 55ms/step - Valid: 0.0927
# For epoch 3, loss 0.09120218 improved from 0.092153564
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009821611>
# 1718/1718 [==============================] - 1129s 169ms/step - Train: 0.0935
# 156/156 [==============================] - 1139s 61ms/step - Valid: 0.0922
# For epoch 4, loss 0.090963595 improved from 0.09120218
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009704457>
# 1718/1718 [==============================] - 1441s 175ms/step - Train: 0.09291s
# 156/156 [==============================] - 1451s 61ms/step - Valid: 0.0920
# For epoch 5, loss 0.090922326 improved from 0.090963595
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009559977>
# 1718/1718 [==============================] - 1755s 177ms/step - Train: 0.0912- Tra
# 156/156 [==============================] - 1764s 59ms/step - Valid: 0.0883 - V
# For epoch 6, loss 0.07005874 improved from 0.090922326
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0009389437>
# 1718/1718 [==============================] - 2066s 175ms/step - Train: 0.0877
# 156/156 [==============================] - ETA: 0s - Valid: 0.0850 - E - 2075s 58ms/step - Valid: 0.0850
# For epoch 7, loss 0.064878464 improved from 0.07005874
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00091943145>
# 1718/1718 [==============================] - 2378s 176ms/step - Train: 0.0847
# 156/156 [==============================] - 2388s 64ms/step - Valid: 0.0822
# For epoch 8, loss 0.063065365 improved from 0.064878464
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0008976278>
# 1718/1718 [==============================] - 2675s 166ms/step - Train: 0.0822
# 156/156 [==============================] - 2683s 55ms/step - Valid: 0.0800
# For epoch 9, loss 0.0619456 improved from 0.063065365
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0008737161>
# 1718/1718 [==============================] - 2952s 156ms/step - Train: 0.0802- T
# 156/156 [==============================] - 2961s 59ms/step - Valid: 0.0781
# For epoch 10, loss 0.06110481 improved from 0.0619456
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0008478938>
# 1718/1718 [==============================] - 3236s 159ms/step - Train: 0.0784
# 156/156 [==============================] - 3245s 55ms/step - Valid: 0.0766
# For epoch 11, loss 0.06115782 did not improve from 0.06110481
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0008203699>
# 1718/1718 [==============================] - 3527s 164ms/step - Train: 0.0768
# 156/156 [==============================] - 3536s 55ms/step - Valid: 0.0751
# For epoch 12, loss 0.059591897 improved from 0.06110481
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0007913619>
# 1718/1718 [==============================] - 3813s 161ms/step - Train: 0.0755- Train
# 156/156 [==============================] - 3823s 60ms/step - Valid: 0.0739
# For epoch 13, loss 0.058766 improved from 0.059591897
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0007610929>
# 1718/1718 [==============================] - 4105s 164ms/step - Train: 0.0743
# 156/156 [==============================] - 4114s 57ms/step - Valid: 0.0728 -
# For epoch 14, loss 0.05872351 improved from 0.058766
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0007297889>
# 1718/1718 [==============================] - 4397s 164ms/step - Train: 0.0732- Train: 0.07
# 156/156 [==============================] - 4406s 58ms/step - Valid: 0.0718
# For epoch 15, loss 0.058199216 improved from 0.05872351
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0006976763>
# 1718/1718 [==============================] - 4689s 164ms/step - Train: 0.0722- Train: 0.07
# 156/156 [==============================] - 4698s 57ms/step - Valid: 0.0710 - Valid: 0.
# For epoch 16, loss 0.058211945 did not improve from 0.058199216
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00066497887>
# 1718/1718 [==============================] - 4982s 165ms/step - Train: 0.0714
# 156/156 [==============================] - ETA: 0s - Valid: 0.07 - 4991s 54ms/step - Valid: 0.0702
# For epoch 17, loss 0.057292603 improved from 0.058199216
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00063191523>
# 1718/1718 [==============================] - 5276s 165ms/step - Train: 0.0706
# 156/156 [==============================] - 5284s 54ms/step - Valid: 0.0695
# For epoch 18, loss 0.0575313 did not improve from 0.057292603
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00059869676>
# 1718/1718 [==============================] - 5568s 165ms/step - Train: 0.0699
# 156/156 [==============================] - 5578s 58ms/step - Valid: 0.0688
# For epoch 19, loss 0.057111006 improved from 0.057292603
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00056552544>
# 1718/1718 [==============================] - 5864s 166ms/step - Train: 0.0692
# 156/156 [==============================] - 5869s 36ms/step - Valid: 0.0682 - Valid:  - ETA
# For epoch 20, loss 0.056752007 improved from 0.057111006
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0005325918>
# 1718/1718 [==============================] - 6162s 169ms/step - Train: 0.0686
# 156/156 [==============================] - 6172s 64ms/step - Valid: 0.0677
# For epoch 21, loss 0.056762177 did not improve from 0.056752007
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00050007354>
# 1718/1718 [==============================] - 6462s 168ms/step - Train: 0.0681
# 156/156 [==============================] - 6469s 47ms/step - Valid: 0.0672
# For epoch 22, loss 0.056283448 improved from 0.056752007
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0004681343>
# 1718/1718 [==============================] - 6756s 166ms/step - Train: 0.0675
# 156/156 [==============================] - 6765s 60ms/step - Valid: 0.0667
# For epoch 23, loss 0.05623602 improved from 0.056283448
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00043692222>
# 1718/1718 [==============================] - 7054s 167ms/step - Train: 0.0670
# 156/156 [==============================] - 7060s 41ms/step - Valid: 0.0662
# For epoch 24, loss 0.056114532 improved from 0.05623602
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00040656963>
# 1718/1718 [==============================] - 7345s 165ms/step - Train: 0.0666
# 156/156 [==============================] - 7354s 62ms/step - Valid: 0.0658
# For epoch 25, loss 0.055853136 improved from 0.056114532
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00037719234>
# 1718/1718 [==============================] - 7642s 167ms/step - Train: 0.0662
# 156/156 [==============================] - 7648s 37ms/step - Valid: 0.0654
# For epoch 26, loss 0.055913087 did not improve from 0.055853136
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0003488895>
# 1718/1718 [==============================] - 7929s 163ms/step - Train: 0.0658
# 156/156 [==============================] - 7939s 58ms/step - Valid: 0.0651
# For epoch 27, loss 0.055539273 improved from 0.055853136
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0003217437>
# 1718/1718 [==============================] - 8226s 167ms/step - Train: 0.0654
# 156/156 [==============================] - 8236s 62ms/step - Valid: 0.0647
# For epoch 28, loss 0.05544135 improved from 0.055539273
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0002958212>
# 1718/1718 [==============================] - 8519s 165ms/step - Train: 0.0650
# 156/156 [==============================] - 8528s 58ms/step - Valid: 0.0644
# For epoch 29, loss 0.05528348 improved from 0.05544135
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00027117252>
# 1718/1718 [==============================] - 8815s 166ms/step - Train: 0.0647
# 156/156 [==============================] - 8823s 55ms/step - Valid: 0.0641
# For epoch 30, loss 0.055174235 improved from 0.05528348
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00024783303>
# 1718/1718 [==============================] - 9113s 167ms/step - Train: 0.0644
# 156/156 [==============================] - 9123s 64ms/step - Valid: 0.0638
# For epoch 31, loss 0.055154182 improved from 0.055174235
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00022582384>
# 1718/1718 [==============================] - 9417s 170ms/step - Train: 0.0641ETA: 1s
# 156/156 [==============================] - 9426s 59ms/step - Valid: 0.0635
# For epoch 32, loss 0.054997675 improved from 0.055154182
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00020515283>
# 1718/1718 [==============================] - 9720s 171ms/step - Train: 0.0638
# 156/156 [==============================] - 9730s 63ms/step - Valid: 0.0633
# For epoch 33, loss 0.05485278 improved from 0.054997675
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00018581568>
# 1718/1718 [==============================] - 10021s 168ms/step - Train: 0.0635
# 156/156 [==============================] - 10028s 50ms/step - Valid: 0.0630
# For epoch 34, loss 0.05519928 did not improve from 0.05485278
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00016779704>
# 1718/1718 [==============================] - 10317s 168ms/step - Train: 0.0632
# 156/156 [==============================] - 10327s 63ms/step - Valid: 0.0628
# For epoch 35, loss 0.054821532 improved from 0.05485278
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.0001510718>
# 1718/1718 [==============================] - 10625s 173ms/step - Train: 0.0630
# 156/156 [==============================] - 10635s 64ms/step - Valid: 0.0626
# For epoch 36, loss 0.05478551 improved from 0.054821532
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.00013560621>
# 1718/1718 [==============================] - 10931s 172ms/step - Train: 0.0627 T
# 156/156 [==============================] - 10940s 56ms/step - Valid: 0.0624
# For epoch 37, loss 0.05484103 did not improve from 0.05478551
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.000121359255>
# 1718/1718 [==============================] - 11231s 169ms/step - Train: 0.0625
# 156/156 [==============================] - 11241s 59ms/step - Valid: 0.0622
# For epoch 38, loss 0.054595325 improved from 0.05478551
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.000108283755>
# 1718/1718 [==============================] - 11530s 168ms/step - Train: 0.0623
# 156/156 [==============================] - 11539s 53ms/step - Valid: 0.0620
# For epoch 39, loss 0.054564744 improved from 0.054595325
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=9.6327625e-05>
# 1718/1718 [==============================] - 11838s 174ms/step - Train: 0.0621
# 156/156 [==============================] - 11847s 61ms/step - Valid: 0.0618
# For epoch 40, loss 0.054501694 improved from 0.054564744
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=8.543494e-05>
# 1718/1718 [==============================] - 12136s 166ms/step - Train: 0.0619
# 156/156 [==============================] - 12145s 53ms/step - Valid: 0.0616
# For epoch 41, loss 0.05444932 improved from 0.054501694
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=7.554701e-05>
# 1718/1718 [==============================] - 12439s 171ms/step - Train: 0.0617 T
# 156/156 [==============================] - 12448s 58ms/step - Valid: 0.0614
# For epoch 42, loss 0.054503582 did not improve from 0.05444932
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=6.660337e-05>
# 1718/1718 [==============================] - 12687s 139ms/step - Train: 0.0615
# 156/156 [==============================] - 12690s 17ms/step - Valid: 0.0613
# For epoch 43, loss 0.05443054 improved from 0.05444932
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=5.8542624e-05>
# 1718/1718 [==============================] - 12786s 56ms/step - Train: 0.0613
# 156/156 [==============================] - 12789s 17ms/step - Valid: 0.0611
# For epoch 44, loss 0.05433719 improved from 0.05443054
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=5.13033e-05>
# 1718/1718 [==============================] - 12886s 56ms/step - Train: 0.0612
# 156/156 [==============================] - 12889s 18ms/step - Valid: 0.0610
# For epoch 45, loss 0.054346465 did not improve from 0.05433719
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=4.4824512e-05>
# 1718/1718 [==============================] - 12986s 57ms/step - Train: 0.0610
# 156/156 [==============================] - 12989s 18ms/step - Valid: 0.0608
# For epoch 46, loss 0.054379452 did not improve from 0.05433719
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=3.9046576e-05>
# 1718/1718 [==============================] - 13087s 57ms/step - Train: 0.0609
# 156/156 [==============================] - 13090s 17ms/step - Valid: 0.0607
# For epoch 47, loss 0.05431486 improved from 0.05433719
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=3.3911536e-05>
# 1718/1718 [==============================] - 13190s 58ms/step - Train: 0.0607- ETA: 0s - T
# 156/156 [==============================] - 13193s 18ms/step - Valid: 0.0605
# For epoch 48, loss 0.054272633 improved from 0.05431486
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=2.9363584e-05>
# 1718/1718 [==============================] - 13290s 56ms/step - Train: 0.0606
# 156/156 [==============================] - 13293s 17ms/step - Valid: 0.0604
# For epoch 49, loss 0.05427778 did not improve from 0.054272633
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=2.5349405e-05>
# 1718/1718 [==============================] - 13391s 57ms/step - Train: 0.0604
# 156/156 [==============================] - 13394s 18ms/step - Valid: 0.0603
# For epoch 50, loss 0.054270048 improved from 0.054272633
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=2.1818436e-05>
# 1718/1718 [==============================] - 13491s 55ms/step - Train: 0.0603
# 156/156 [==============================] - 13493s 17ms/step - Valid: 0.0602
# For epoch 51, loss 0.054261953 improved from 0.054270048
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=1.8723049e-05>
# 1718/1718 [==============================] - 13589s 55ms/step - Train: 0.0602- Train
# 156/156 [==============================] - 13591s 17ms/step - Valid: 0.0601
# For epoch 52, loss 0.05425499 improved from 0.054261953
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=1.6018676e-05>
# 1718/1718 [==============================] - 13687s 55ms/step - Train: 0.0601
# 156/156 [==============================] - 13690s 17ms/step - Valid: 0.0600
# For epoch 53, loss 0.05425738 did not improve from 0.05425499
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=1.3663872e-05>
# 1718/1718 [==============================] - 13785s 55ms/step - Train: 0.0599
# 156/156 [==============================] - 13788s 17ms/step - Valid: 0.0598
# For epoch 54, loss 0.05425454 improved from 0.05425499
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=1.162032e-05>
# 1718/1718 [==============================] - 13891s 60ms/step - Train: 0.0598
# 156/156 [==============================] - 13894s 17ms/step - Valid: 0.0597
# For epoch 55, loss 0.05424244 improved from 0.05425454
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=9.852796e-06>
# 1718/1718 [==============================] - ETA: 0s - Train: 0.0597 - ETA: 53s - Trai - ETA: 47s - Train:  - E -  - ETA: 42s - Train: 0.05 - ETA: 42s - Train: 0. - ET - ETA: 0s - Train: 0.05 - ETA: 0s - Tra - 13998s 60ms/step - Train: 0.0597
# 156/156 [==============================] - 14001s 18ms/step - Valid: 0.0596
# For epoch 56, loss 0.054233238 improved from 0.05424244
# Learning rate: <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=9.852796e-06>
# 1026/1718 [================>.............] - ETA: 42s - Train: 0.0596- ETA: 51s - Train: 0.059  - ETA: 48s - ETA:

# %% [markdown]
# # Training Classifcation Model
